# %% [markdown]
# Dynamical system is a system in which a function describes the time dependance of a point in a geometrical space.
#
#
# The evolution rule of the dynamical system is a function that describe what future states fllow from the current state. In a deterministic system, only one future state follows the current given state. For stochastic systems, random events also effects the evolution of state variables.
#
#
#
# In physics, a **Dynamical System** is `a particle or an ensable of particals whose state varies over time and thsu obeys the differential equations involving time derivatives`
#
# In  order to predict the future state of the system we can use 1) analytical solution of these equations or 2) INtegrator on a computer
#
# Now a days we use a computer to predict the future state of a given dynamial system and those methods are called `Numerical methods`. In these methods one start with an initial condition of the system and then use an integrator to iterate the underlying differential equation (or deference equation) many times. This procedire is called as **integrating the system** and the collection of all future states of the system for agiven inital condition is called as an **Orbit**

# %% [markdown]
# **NIT**
# 1. Newtons laws of motion
# 2. Pendulums
#     - simple
#     - forced
#     - damped
#     - damped + forced
#
# 3. Springs
# 4. Collisions

# %% [markdown]
# **Comp eng**
#
# 1. Elasticity
# 2. PLasticity
# 3. Visco elastic
# 4. Navier stokes
#
# **electrical department**
# 1. Poission equation
# 2. Heat equation
# 3. Reaction -Diffusion equation
# 4. Electrommagnetism (Maxwell equations)
# 5. Plasma
#
# **ICAMS**
# 1. Schrodinger Equation
# 2. Molecular dynamics
# 3. Phase field

# %% [markdown]
# ## Numerical Methods

# %% [markdown]
# Numerical integration methods are algorithems to calculate the numerical value of a definite integral or for numericla solution for differential equation.
#
# The basic problem in numerical integration is to compute an approximate solution to a definite integral
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# NUmerical integration methods can be described as combining evaluations of integrand to get the approximation to the integral. The integral is calculated over a set of finite points called integrationpoints and a weighted sum of these values is used to approximate the integral.

# %% [markdown]
# ## Numerical Integrators

# %% [markdown]
# #### 1. Mid point rule

# %% [markdown]
# The function is interpolated as a contant function between teh known integration points

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. Trapizoidal rule

# %% [markdown]
# The function is interpolated as a straight line between the integration points

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. Numerical methods for Ordinary Differential Equations

# %% [markdown]
# These are the numerical approximate solutions of ODE and these methods are also called as numerical integration.
#
# NUmerical methods for
#
# **2.1 Initial value problems**: Here we have both ODE and
# and the initial condition which specifies the value of unknown function ata given pooint in the domain. The task here is to indetify how the system evolves in time given the initial conditions of the problem
#
#
# **2.2 Boundary value problems**: Here along with the differentia lequation we have the additional boundary conditions that the system must satisfy.
#
#
# Boundary value problems are similar to initial value problems. A boundary value problem has conditions specified at the extremes ("boundaries") of the independent variable in the equation whereas an initial value problem has all of the conditions specified at the same value of the independent variable (and that value is at the lower boundary of the domain, thus the term "initial" value).![image.png](attachment:image.png)
#
#
# In a BVP, one defines values, or components of the solution y at more than one point.  here we use Finite difference methods or finite element methods to solve the differentia lequation

# %% [markdown]
# ### 2.1 Inital Value problems
#
# ![image.png](attachment:image.png)
#
# First order IVP are soleved using Linear multistep methods or single methods
#
# We will learn only about single step methods. Here we start with a initial point and then take a short step forward in time to find the next solution point. Like this we find many intermediate solutions with csusequent small steps.
#
# **Euler's method:** Here refer to only one previous point and its derivative to determine the current value.
#
# **Runge–Kutta method:** Here we take some intermediate steps (for example, a half-step) to obtain a higher order method, but then discard all previous information before taking a second step.

# %% [markdown]
# ### 2.1.1 Eulers method

# %% [markdown]
# From any point on a curve we can find teh approximation of a nearby point on the curve by moving short distance alomg a line tangent to the curve
#
# **forward euler**
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Back ward euler**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.1.2 Boundary Value Problem
#
#
# ![image.png](attachment:image.png)
#
# **Finite Difference Method**
#
#
# **Finite Element MEthod**

# %% [markdown]
# **Basic Solvers**
# 1. Newton rapson
# 2. Modified Newton rapson
# 4. Range kutha integrator
# 5. Gradient descent
# 6. Conjugate grsysmnt descent
# 7.
#
#
# **Finite Difference methods**
# 1. Forword Euler
# 2. Backword Euler
# 3. Central diff
