# %% [markdown]
# # Two Variable Linear Systems (Oscillations)

# %% [markdown]
# 1. Linear Oscillator (Harmonic Oscillator)
# 2. Mass and spring
# 3. RLC circuit
# 4. Two-Body problem (Kepler-Newton)

# %% [markdown]
# # 1. Linear Oscillator (harmonic Oscillator)

# %% [markdown]
# ![](https://i.pinimg.com/originals/0f/a5/3f/0fa53fb77f5c9d7c72d26d7bf935ba26.gif)

# %% [markdown]
# In classical mechanics a harmonic oscillator is a system that, when displaced from its equilibrium position experiences a restoring force F proprtional to the displacement X.
#
# The harmonic oscillator model is very important in physics, because any mass subject to a force in stable equilibrium acts as a harmonic oscillator for small vibrations. They are the source of virtually all sinusoidal vibrations and waves.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.1 Simple pendulum

# %% [markdown]
# ![](https://i.pinimg.com/originals/3b/c1/91/3bc191f99c669acb32b4af9977a21041.gif)

# %% [markdown]
# A simple pendulum exhibits aproximaely simple harmonic motion under conditions of no damping and small amplitude. teh differential equation governing the simple pendulum is ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Spring Mass system

# %% [markdown]
# ![image.png](https://nextjournal.com/data/QmTsBwdYtvG2oSs2VMy7XPQEji6yRcAxiCjmpdoXTGm2cQ?filename=Harmonic2.gif&content-type=image/gif)

# %% [markdown]
# When a spring is streched or compressed by a mass, the spring develps a restoring force. Hookes law gives us the relation between force exerted by the spring when the spring $F(t)$ is copressed or streched ata certain length $x$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# k: Spring constant
# x: displacesment of mass at time t with respect tothe equilibrium position. the minus sign indicates taht the force exerted by the system is in opposite direction.

# %% [markdown]
# By using the force balance (Newton's second law of motion) or energy method we can frame the equation of motion of the spring-mass systemas a differential equation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. RLC Circiut

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# An RLC series circuit can be modeled by the same differential equation as a mass-spring system.

# %% [markdown]
# An RLC circuit is an electrical circuit consisting of a resistor (R), an inductor (L), and a capacitor (C), connected in series or in parallel.

# %% [markdown]
# Teh circiut forms a harmonic oscillator for the current and resonates in a similar way as LC circuit. RLC circuits are used in Radio receivers, TV to tune and selcet a specific frequency range from ambient radio waves. The voltage or current in the circuit at any time is defined by the second-order diferentail equation in circuit analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# q(t): charge on the capacitor
# I(t): current in the RLC circuit
# L:   Inductance
# R : resistance
# C: capacitance
# E(t): electric potential

# %% [markdown]
# # 4. Two body problem

# %% [markdown]
# ![image.png](https://upload.wikimedia.org/wikipedia/commons/0/0e/Orbit5.gif)

# %% [markdown]
# IN calssical mechanics two-body problem is to predict the motion of two massive objects. The problem assumes that the two objects interact only with one another; the only force afecting each object arises fro teh other one ans all other object are ignored

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The goal of this problem is to see why particles moving in an inverse square force law — for example,
# gravity! — move along nice curves like ellipses, parabolas and hyperbolas. This is called the Kepler
# problem since it was Kepler who discovered that the orbits of planets were elliptical, and explaining
# this was the first major triumph of Newtonian mechanics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
